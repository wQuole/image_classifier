# %%
import os
import random
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# Set constant
from datetime import datetime
NOW  = datetime.now().strftime("%m%d%Y_%H:%M%S")

# %% [markdown]
# # Prepare data

# %%
training_data = os.listdir('./data/training')


labels = []
for filename in training_data:
    label = filename.split('.')[0]
    if label == 'cat':
        labels.append(0)
    else:
        labels.append(1)

df = pd.DataFrame({
    'name': training_data,
    'labels': labels
})

# %%
testing_data = os.listdir('./data/testing')


test_df = pd.DataFrame({
    'name': testing_data,
})
number_of_test_sampless = test_df.shape[0]

# %% [markdown]
# ### Change labels from int to string to fit requirements for ImageDataGenerator

# %%
df['labels'] = df['labels'].replace({0: 'cat', 1: 'dog'})

# %% [markdown]
# ### Split training data into 75% training, and 25% validation

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)

train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %% [markdown]
# # Data Generators

# %% [markdown]
# ## Training

# %%
train_datagenerator = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2
)

train_generator = train_datagenerator.flow_from_dataframe(
    train_df, 
    "./data/training/", 
    x_col='name',
    y_col='labels',
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=16
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Validation

# %%
validation_datagenerator = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagenerator.flow_from_dataframe(
    validate_df, 
    "./data/training/", 
    x_col='name',
    y_col='labels',
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=16
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Testing

# %%
testing_datagenerator = ImageDataGenerator(rescale=1./255)
testing_generator = testing_datagenerator.flow_from_dataframe(
    test_df, 
    "./data/testing/", 
    x_col='name',
    y_col=None,
    class_mode=None,
    batch_size=16,
    target_size=(224, 224),
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %% [markdown]
# ## Visualize example of generated training data

# %%
sample_df = train_df.sample(n=1).reset_index(drop=True)
sample_generator = train_datagenerator.flow_from_dataframe(
    sample_df, 
    "./data/training/",
    x_col='name',
    y_col='labels',
    target_size=(224, 224),
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(16):
    plt.subplot(4, 4, i+1)
    for X, Y in sample_generator:
        image = X[0]
        plt.imshow(image)
        plt.xticks([])
        plt.yticks([])
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Training: fit model on training data

# %%
TOTAL_TRAINING_SIZE = train_df.shape[0]
TOTAL_VALIDATION_SIZE = validate_df.shape[0]
BATCH_SIZE = 32
EPOCHS = 10

# %% [markdown]
# ## Introduce early stopping and handle plateauing

# %%
early_stopping = EarlyStopping(patience=5, verbose=True)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_accuracy',
                                        patience=2,
                                        verbose=True,
                                        factor=0.5,
                                        min_lr=1e-5)

# %% [markdown]
# # Finetuning VGG16

# %%
# Configure GPU
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU') 
for physical_device in physical_devices: 
    tf.config.experimental.set_memory_growth(physical_device, True)

# %%
# Configure GPU
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU') 
for physical_device in physical_devices: 
    tf.config.experimental.set_memory_growth(physical_device, True)# Configure GPU
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU') 
for physical_device in physical_devices: 
    tf.config.experimental.set_memory_growth(physical_device, True)

# %%
from models.pretrained_vgg16 import PretrainedVGG16
vgg16_model = PretrainedVGG16((224, 224, 3)).model

vgg16_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              102761472
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 110,398,786
# Trainable params: 102,763,522
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
vgg16_model_history = vgg16_model.fit(
    x=train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=TOTAL_VALIDATION_SIZE//BATCH_SIZE,
    steps_per_epoch=TOTAL_TRAINING_SIZE//BATCH_SIZE,
    callbacks=[early_stopping, reduce_learning_rate])
# Out:
# Epoch 1/10
# 625/625 [==============================] - 84s 134ms/step - loss: 0.7508 - accuracy: 0.5048 - val_loss: 0.7564 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 2/10
# 625/625 [==============================] - 84s 135ms/step - loss: 0.7540 - accuracy: 0.4984 - val_loss: 0.7522 - val_accuracy: 0.5020 - lr: 0.0010
# Epoch 3/10
# 625/625 [==============================] - 86s 137ms/step - loss: 0.7522 - accuracy: 0.5021 - val_loss: 0.7526 - val_accuracy: 0.5012 - lr: 0.0010
# Epoch 4/10
# 625/625 [==============================] - ETA: 0s - loss: 0.7541 - accuracy: 0.4982
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 [==============================] - 84s 134ms/step - loss: 0.7541 - accuracy: 0.4982 - val_loss: 0.7546 - val_accuracy: 0.4972 - lr: 0.0010
# Epoch 5/10
# 625/625 [==============================] - 85s 136ms/step - loss: 0.7535 - accuracy: 0.4994 - val_loss: 0.7552 - val_accuracy: 0.4960 - lr: 5.0000e-04
# Epoch 6/10
# 625/625 [==============================] - ETA: 0s - loss: 0.7527 - accuracy: 0.5010
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 [==============================] - 84s 135ms/step - loss: 0.7527 - accuracy: 0.5010 - val_loss: 0.7560 - val_accuracy: 0.4944 - lr: 5.0000e-04
# Epoch 7/10
# 625/625 [==============================] - 88s 140ms/step - loss: 0.7520 - accuracy: 0.5025 - val_loss: 0.7608 - val_accuracy: 0.4848 - lr: 2.5000e-04
# Epoch 00007: early stopping

# %%
vgg16_model.save_weights(f"finetuned_vgg16_{NOW}.h5")

# %%
# https://www.tensorflow.org/tutorials/images/classification#visualize_training_results
def tf_plot(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss=history.history['loss']
    val_loss=history.history['val_loss']

    epochs_range = range(EPOCHS)

    plt.figure(figsize=(16, 9))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range[:7], acc, label='Training Accuracy')
    plt.plot(epochs_range[:7], val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range[:7], loss, label='Training Loss')
    plt.plot(epochs_range[:7], val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
tf_plot(vgg16_model_history)
